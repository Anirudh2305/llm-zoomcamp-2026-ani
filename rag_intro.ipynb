# %%
from openai import OpenAI
import os

# %%
client = OpenAI(
    api_key=os.getenv("NVIDIA_API_KEY"),
    base_url="https://integrate.api.nvidia.com/v1"
)

# %%
def llm(prompt):
    response = client.responses.create(
        model="openai/gpt-oss-120b",
        input=prompt
    )
    return response.output_text

# %%
llm("Good Morning!")
# Out:
# 'Good morning! 🌞 How’s your day shaping up so far? Let me know if there’s anything I can help you with today.'

# %%
question = "I just discovered the course. Can I join now?"
answer = llm(question)
print(answer)
# Out:
# Absolutely—you can typically enroll in a course at any time, as long as it’s still open for registration. Here’s a quick checklist to get you started:
#
# | Step | What to Do | Why It Helps |
# |------|------------|--------------|
# | **1️⃣ Identify the Course** | Let us know the exact title or code (e.g., “Intro to Data Science – Fall 2024”). | We can give you the most accurate enrollment links, prerequisites, and schedule. |
# | **2️⃣ Check Availability** | Most programs list open‑enrollment periods on their website or in the course catalog. | Ensures the class isn’t already full or past its start date. |
# | **3️⃣ Meet Prerequisites** | Review any required background (e.g., “basic Python knowledge” or “completed Calculus I”). | Guarantees you’re set up for success and avoids registration holds. |
# | **4️⃣ Gather Required Docs** | Some courses need a transcript, proof of identity, or a brief statement of purpose. | Helps the admin team process your application quickly. |
# | **5️⃣ Register Online** | Use the institution’s portal (often a “Register/Enroll” button) or fill out a short enrollment form. | This officially adds you to the class roster. |
# | **6️⃣ Pay Fees (if applicable)** | Submit tuition, course fees, or a deposit through the payment portal. | Secures your spot—many courses are “first‑come, first‑served.” |
# | **7️⃣ Confirm & Get Access** | After payment, you’ll receive a confirmation email with login credentials for the learning platform (Canvas, Moodle, Blackboard, etc.). | Gives you immediate entry to course materials, syllabus, and the discussion board. |
# | **8️⃣ Start Engaging** | Introduce yourself in the welcome forum, download the syllabus, and note the first assignment deadline. | Jump‑starts your learning journey and connects you with classmates. |
#
# ### Quick Tips
#
# - **Deadlines:** If the course follows a semester system, enrollment often closes a week or two before the first class. For self‑paced or rolling‑admission courses, you can join anytime.
# - **Waitlists:** If the class is full, ask if there’s a waitlist. Spots often open up as other students drop or defer.
# - **Financial Aid/Scholarships:** If you need assistance, check the “Financial Services” or “Scholarships” page early—some aid requires a separate application.
# - **Technical Requirements:** Make sure you have a reliable internet connection and any required software (e.g., Zoom, Jupyter Notebook) installed before the start date.
#
# ---
#
# #### How We Can Help Further
# 1. **Send the Exact Course Name** – I can pull up the specific enrollment link and any special instructions.
# 2. **Prerequisite Check** – Tell me your background; I’ll let you know if you meet the requirements or suggest a prep module.
# 3. **Financial Questions** – I can point you to tuition calculators, payment plans, or scholarship opportunities.
# 4. **Technical Setup** – Need help configuring the learning platform? I can walk you through a quick setup guide.
#
# Just let me know which of the above (or anything else) you’d like to explore, and we’ll get you signed up and ready to go! 🚀

# %%
context = """
I just discovered the course. Can I still join?
Yes, but if you want to receive a certificate, you need to submit your project while we're still accepting submissions.

Course: I have registered for the LLM Zoomcamp. When can I expect to receive the confirmation email?
You don't need it. You're accepted. You can also just start learning and submitting homework (while the form is open) without registering. It is not checked against any registered list. Registration is just to gauge interest before the start date.

What is the video/zoom link to the stream for the "Office Hours" or live/workshop sessions?
The zoom link is only published to instructors/presenters/TAs. Students participate via YouTube Live and submit questions to Slido.

Cloud alternatives with GPU
Check the quota and reset cycle carefully. Potential options include Google Colab, Kaggle, Databricks.
"""

prompt = f"""
Your task is to answer questions from the course participants
based on the provided context.

Use the context to find relevant information and provide accurate
answers. If the answer is not found in the context,
respond with "I don't know."

Question:
{question}

Context:
{context}
"""

# %%
answer = llm(prompt)
print(answer)
# Out:
# Yes—you can still join the course. Just jump in and start learning. If you’d like to earn a certificate, make sure you submit your final project before the submission window closes.

# %%
question_2 = "What is the mininum marks I need to score to pass?"

prompt_noq = f"""
Your task is to answer questions from the course participants
based on the provided context.

Use the context to find relevant information and provide accurate
answers. If the answer is not found in the context,
respond with "I don't know."

Question:
{question_2}

Context:
{context}
"""

# %%
answer = llm(prompt_noq)
print(answer)
# Out:
# I don't know.

# %%
def rag(question):
    search_results = search(question)
    user_prompt = build_prompt(question, search_results)
    return llm(user_prompt)
